# %%
import polars as pl
import numpy as np
# Create a random seed for reproducibility
np.random.seed(42)
# Dataset 1: User information
data1 = {
'user_id': np.arange(1, 101),
'name': np.random.choice(['Alice', 'Bob', 'Charlie', 'David'], 100)
}
df1 = pl.DataFrame(data1)
# Dataset 2: User age information
data2 = {
'user_id': np.arange(51, 151),
'age': np.random.randint(18, 65, size=100)
}
df2 = pl.DataFrame(data2)
# Dataset 3: User scores
data3 = {
'user_id': np.random.randint(1, 101, size=100),
'score': np.random.randint(200, 1000, size=100)
}
df3 = pl.DataFrame(data3)

# %%
df1
# Out:
# shape: (100, 2)
# ┌─────────┬─────────┐
# │ user_id ┆ name    │
# │ ---     ┆ ---     │
# │ i64     ┆ str     │
# ╞═════════╪═════════╡
# │ 1       ┆ Charlie │
# │ 2       ┆ David   │
# │ 3       ┆ Alice   │
# │ 4       ┆ Charlie │
# │ 5       ┆ Charlie │
# │ …       ┆ …       │
# │ 96      ┆ Bob     │
# │ 97      ┆ Bob     │
# │ 98      ┆ David   │
# │ 99      ┆ Bob     │
# │ 100     ┆ Alice   │
# └─────────┴─────────┘

# %%
df2
# Out:
# shape: (100, 2)
# ┌─────────┬─────┐
# │ user_id ┆ age │
# │ ---     ┆ --- │
# │ i64     ┆ i32 │
# ╞═════════╪═════╡
# │ 51      ┆ 35  │
# │ 52      ┆ 43  │
# │ 53      ┆ 61  │
# │ 54      ┆ 51  │
# │ 55      ┆ 27  │
# │ …       ┆ …   │
# │ 146     ┆ 39  │
# │ 147     ┆ 45  │
# │ 148     ┆ 19  │
# │ 149     ┆ 59  │
# │ 150     ┆ 62  │
# └─────────┴─────┘

# %%
df3
# Out:
# shape: (100, 2)
# ┌─────────┬───────┐
# │ user_id ┆ score │
# │ ---     ┆ ---   │
# │ i32     ┆ i32   │
# ╞═════════╪═══════╡
# │ 62      ┆ 672   │
# │ 57      ┆ 350   │
# │ 6       ┆ 614   │
# │ 28      ┆ 497   │
# │ 28      ┆ 810   │
# │ …       ┆ …     │
# │ 82      ┆ 944   │
# │ 1       ┆ 236   │
# │ 11      ┆ 479   │
# │ 92      ┆ 548   │
# │ 57      ┆ 696   │
# └─────────┴───────┘

# %%
inner_joined_df = df1.join(df2, on='user_id', how='inner')
print("Inner Join Result:\n", inner_joined_df.head())
# Out:
# Inner Join Result:
#  shape: (5, 3)
# ┌─────────┬─────────┬─────┐
# │ user_id ┆ name    ┆ age │
# │ ---     ┆ ---     ┆ --- │
# │ i64     ┆ str     ┆ i32 │
# ╞═════════╪═════════╪═════╡
# │ 51      ┆ Charlie ┆ 35  │
# │ 52      ┆ Bob     ┆ 43  │
# │ 53      ┆ Charlie ┆ 61  │
# │ 54      ┆ David   ┆ 51  │
# │ 55      ┆ Charlie ┆ 27  │
# └─────────┴─────────┴─────┘

# %%
left_joined_df = df1.join(df2, on='user_id', how='left')
print("Left Join Result:\n",
left_joined_df.sample(10).head())
# Out:
# Left Join Result:
#  shape: (5, 3)
# ┌─────────┬─────────┬──────┐
# │ user_id ┆ name    ┆ age  │
# │ ---     ┆ ---     ┆ ---  │
# │ i64     ┆ str     ┆ i32  │
# ╞═════════╪═════════╪══════╡
# │ 35      ┆ Bob     ┆ null │
# │ 10      ┆ Bob     ┆ null │
# │ 86      ┆ Charlie ┆ 28   │
# │ 69      ┆ David   ┆ 41   │
# │ 2       ┆ David   ┆ null │
# └─────────┴─────────┴──────┘

# %%
full_outer_joined_df = df1.join(df2, on='user_id',
how='full')
print("Full Outer Join Result:\n",
full_outer_joined_df.sample(10).head())
# Out:
# Full Outer Join Result:
#  shape: (5, 4)
# ┌─────────┬─────────┬───────────────┬──────┐
# │ user_id ┆ name    ┆ user_id_right ┆ age  │
# │ ---     ┆ ---     ┆ ---           ┆ ---  │
# │ i64     ┆ str     ┆ i64           ┆ i32  │
# ╞═════════╪═════════╪═══════════════╪══════╡
# │ 97      ┆ Bob     ┆ 97            ┆ 24   │
# │ null    ┆ null    ┆ 137           ┆ 56   │
# │ 48      ┆ Charlie ┆ null          ┆ null │
# │ 63      ┆ Alice   ┆ 63            ┆ 57   │
# │ 71      ┆ Bob     ┆ 71            ┆ 42   │
# └─────────┴─────────┴───────────────┴──────┘

# %%
df_brands = pl.DataFrame({
'brand': ['lacoste', 'prada', 'calvin klein']
})
df_sizes = pl.DataFrame({
'sizes': ['S', 'M', 'L']
})
cross_joined_df = df_brands.join(df_sizes, how='cross')
print("Cross Join Result (first 5 rows):\n",
cross_joined_df)
# Out:
# Cross Join Result (first 5 rows):
#  shape: (9, 2)
# ┌──────────────┬───────┐
# │ brand        ┆ sizes │
# │ ---          ┆ ---   │
# │ str          ┆ str   │
# ╞══════════════╪═══════╡
# │ lacoste      ┆ S     │
# │ lacoste      ┆ M     │
# │ lacoste      ┆ L     │
# │ prada        ┆ S     │
# │ prada        ┆ M     │
# │ prada        ┆ L     │
# │ calvin klein ┆ S     │
# │ calvin klein ┆ M     │
# │ calvin klein ┆ L     │
# └──────────────┴───────┘

# %%
semi_joined_df = df1.join(df2, on='user_id', how='semi')
print(f"Semi Join Result {semi_joined_df.shape}:\n",
semi_joined_df.head())
# Out:
# Semi Join Result (50, 2):
#  shape: (5, 2)
# ┌─────────┬─────────┐
# │ user_id ┆ name    │
# │ ---     ┆ ---     │
# │ i64     ┆ str     │
# ╞═════════╪═════════╡
# │ 51      ┆ Charlie │
# │ 52      ┆ Bob     │
# │ 53      ┆ Charlie │
# │ 54      ┆ David   │
# │ 55      ┆ Charlie │
# └─────────┴─────────┘

# %%
semi_joined_df = df2.join(df1, on='user_id', how='semi')
print(f"Semi Join Result {semi_joined_df.shape}:\n",
semi_joined_df.head())
# Out:
# Semi Join Result (50, 2):
#  shape: (5, 2)
# ┌─────────┬─────┐
# │ user_id ┆ age │
# │ ---     ┆ --- │
# │ i64     ┆ i32 │
# ╞═════════╪═════╡
# │ 51      ┆ 35  │
# │ 52      ┆ 43  │
# │ 53      ┆ 61  │
# │ 54      ┆ 51  │
# │ 55      ┆ 27  │
# └─────────┴─────┘

# %%
anti_joined_df = df1.join(df2, on='user_id', how='anti')
print(f"Anti Join Result {anti_joined_df.shape}:\n",
anti_joined_df.head())
# Out:
# Anti Join Result (50, 2):
#  shape: (5, 2)
# ┌─────────┬─────────┐
# │ user_id ┆ name    │
# │ ---     ┆ ---     │
# │ i64     ┆ str     │
# ╞═════════╪═════════╡
# │ 1       ┆ Charlie │
# │ 2       ┆ David   │
# │ 3       ┆ Alice   │
# │ 4       ┆ Charlie │
# │ 5       ┆ Charlie │
# └─────────┴─────────┘

# %%
import polars as pl
df_q = pl.DataFrame({
"time": ["2024-01-01 10:00", "2024-01-01 10:02", "2024-01-01 10:05"],
"quantity": [10, 20, 30]
}).with_columns(pl.col("time").str.strptime(pl.Datetime)).sort('time')
df_p = pl.DataFrame({
"time": ["2024-01-01 10:01", "2024-01-01 10:03", "2024-01-01 10:06"],
"price": [100, 200, 300]
}).with_columns(pl.col("time").str.strptime(pl.Datetime)).sort('time')
# Выполнение объединения по принципу asof
result = df_q.join_asof(df_p, on="time")
print(result)
# Out:
# shape: (3, 3)
# ┌─────────────────────┬──────────┬───────┐
# │ time                ┆ quantity ┆ price │
# │ ---                 ┆ ---      ┆ ---   │
# │ datetime[μs]        ┆ i64      ┆ i64   │
# ╞═════════════════════╪══════════╪═══════╡
# │ 2024-01-01 10:00:00 ┆ 10       ┆ null  │
# │ 2024-01-01 10:02:00 ┆ 20       ┆ 100   │
# │ 2024-01-01 10:05:00 ┆ 30       ┆ 200   │
# └─────────────────────┴──────────┴───────┘

# %%
df_q, df_p
# Out:
# (shape: (3, 2)
#  ┌─────────────────────┬──────────┐
#  │ time                ┆ quantity │
#  │ ---                 ┆ ---      │
#  │ datetime[μs]        ┆ i64      │
#  ╞═════════════════════╪══════════╡
#  │ 2024-01-01 10:00:00 ┆ 10       │
#  │ 2024-01-01 10:02:00 ┆ 20       │
#  │ 2024-01-01 10:05:00 ┆ 30       │
#  └─────────────────────┴──────────┘,
#  shape: (3, 2)
#  ┌─────────────────────┬───────┐
#  │ time                ┆ price │
#  │ ---                 ┆ ---   │
#  │ datetime[μs]        ┆ i64   │
#  ╞═════════════════════╪═══════╡
#  │ 2024-01-01 10:01:00 ┆ 100   │
#  │ 2024-01-01 10:03:00 ┆ 200   │
#  │ 2024-01-01 10:06:00 ┆ 300   │
#  └─────────────────────┴───────┘)

# %%
from datetime import timedelta
# Выполняем объединение asof с допуском 1 минута
result = df_q .join_asof(df_p, on="time", tolerance=timedelta(minutes=1))
print(result)
# Out:
# shape: (3, 3)
# ┌─────────────────────┬──────────┬───────┐
# │ time                ┆ quantity ┆ price │
# │ ---                 ┆ ---      ┆ ---   │
# │ datetime[μs]        ┆ i64      ┆ i64   │
# ╞═════════════════════╪══════════╪═══════╡
# │ 2024-01-01 10:00:00 ┆ 10       ┆ null  │
# │ 2024-01-01 10:02:00 ┆ 20       ┆ 100   │
# │ 2024-01-01 10:05:00 ┆ 30       ┆ null  │
# └─────────────────────┴──────────┴───────┘

# %%
df11 = pl.DataFrame({
"Name": ["John", "Joseph", "Albert"],
"Age": [18, 15, 29]
}).sort("Age")
df12 = pl.DataFrame({
"Name": ["Ema", "Andrew", "Michel"],
"Age": [22, 30, 16]
}).sort("Age")
df13 = df11.merge_sorted(df12, "Age")
print(df13)
# Out:
# shape: (6, 2)
# ┌────────┬─────┐
# │ Name   ┆ Age │
# │ ---    ┆ --- │
# │ str    ┆ i64 │
# ╞════════╪═════╡
# │ Joseph ┆ 15  │
# │ Michel ┆ 16  │
# │ John   ┆ 18  │
# │ Ema    ┆ 22  │
# │ Albert ┆ 29  │
# │ Andrew ┆ 30  │
# └────────┴─────┘

# %%
df21 = pl.DataFrame({
"Name": ["Alice", "Bob"],
"Age": [25, 30]
})
df22 = pl.DataFrame({
"Name": ["Charlie", "David"],
"Age": [27, 40]
})
df_vertical = pl.concat([df21, df22])
print(df_vertical)
# Out:
# shape: (4, 2)
# ┌─────────┬─────┐
# │ Name    ┆ Age │
# │ ---     ┆ --- │
# │ str     ┆ i64 │
# ╞═════════╪═════╡
# │ Alice   ┆ 25  │
# │ Bob     ┆ 30  │
# │ Charlie ┆ 27  │
# │ David   ┆ 40  │
# └─────────┴─────┘

# %%
df23 = pl.DataFrame({
"City": ["New York", "Los Angeles"],
"Occupation": ["Engineer", "Doctor"]
})
df_horizontal = pl.concat([df21, df23],
how="horizontal")
print(df_horizontal)
# Out:
# shape: (2, 4)
# ┌───────┬─────┬─────────────┬────────────┐
# │ Name  ┆ Age ┆ City        ┆ Occupation │
# │ ---   ┆ --- ┆ ---         ┆ ---        │
# │ str   ┆ i64 ┆ str         ┆ str        │
# ╞═══════╪═════╪═════════════╪════════════╡
# │ Alice ┆ 25  ┆ New York    ┆ Engineer   │
# │ Bob   ┆ 30  ┆ Los Angeles ┆ Doctor     │
# └───────┴─────┴─────────────┴────────────┘

# %%
df_diagonal = pl.concat(
[
df21,
df23,
],
how="diagonal",
)
print(df_diagonal)
# Out:
# shape: (4, 4)
# ┌───────┬──────┬─────────────┬────────────┐
# │ Name  ┆ Age  ┆ City        ┆ Occupation │
# │ ---   ┆ ---  ┆ ---         ┆ ---        │
# │ str   ┆ i64  ┆ str         ┆ str        │
# ╞═══════╪══════╪═════════════╪════════════╡
# │ Alice ┆ 25   ┆ null        ┆ null       │
# │ Bob   ┆ 30   ┆ null        ┆ null       │
# │ null  ┆ null ┆ New York    ┆ Engineer   │
# │ null  ┆ null ┆ Los Angeles ┆ Doctor     │
# └───────┴──────┴─────────────┴────────────┘

# %%
df = pl.DataFrame({
"Year": [2020, 2021],
"Product A": [100, 150],
"Product B": [90, 120]
})
melted_df = df.melt(id_vars="Year",
value_vars=["Product A", "Product B"],
variable_name="Product",
value_name="Sales")
print(melted_df)
# Out:
# shape: (4, 3)
# ┌──────┬───────────┬───────┐
# │ Year ┆ Product   ┆ Sales │
# │ ---  ┆ ---       ┆ ---   │
# │ i64  ┆ str       ┆ i64   │
# ╞══════╪═══════════╪═══════╡
# │ 2020 ┆ Product A ┆ 100   │
# │ 2021 ┆ Product A ┆ 150   │
# │ 2020 ┆ Product B ┆ 90    │
# │ 2021 ┆ Product B ┆ 120   │
# └──────┴───────────┴───────┘
# C:\Users\jandr\AppData\Local\Temp\ipykernel_13992\547881123.py:6: DeprecationWarning: `DataFrame.melt` is deprecated. Use `unpivot` instead, with `index` instead of `id_vars` and `on` instead of `value_vars`
#   melted_df = df.melt(id_vars="Year",

# %%
import polars as pl
df_employees = pl.DataFrame({
"employee_id": [1, 2, 3, 4],
"name": ["Alice", "Bob", "Charlie", "David"],
"department_id": [101, 102, 103, 101]
})
df_departments = pl.DataFrame({
"department_id": [101, 102, 104],
"department_name": ["HR", "IT", "Finance"]
})
result = df_employees.join(df_departments, on="department_id", how="left")
print(result)
# Out:
# shape: (4, 4)
# ┌─────────────┬─────────┬───────────────┬─────────────────┐
# │ employee_id ┆ name    ┆ department_id ┆ department_name │
# │ ---         ┆ ---     ┆ ---           ┆ ---             │
# │ i64         ┆ str     ┆ i64           ┆ str             │
# ╞═════════════╪═════════╪═══════════════╪═════════════════╡
# │ 1           ┆ Alice   ┆ 101           ┆ HR              │
# │ 2           ┆ Bob     ┆ 102           ┆ IT              │
# │ 3           ┆ Charlie ┆ 103           ┆ null            │
# │ 4           ┆ David   ┆ 101           ┆ HR              │
# └─────────────┴─────────┴───────────────┴─────────────────┘

# %%
import polars as pl
df_students = pl.DataFrame({
"student_id": [1, 2, 3],
"student_name": ["Alice", "Bob", "Charlie"]
})
df_grades = pl.DataFrame({
"id": [1, 2, 4],
"grade": ["A", "B", "C"]
})
result = df_students.join(df_grades, on="student_id", how="inner")

# %%
import polars as pl
df = pl.DataFrame({
"name": ["Alice", "Bob", "Charlie"],
"age": [25, 30, 35],
"city": ["New York", "Los Angeles", "Chicago"]
})
lazy_df = df.lazy()
lazy_df
# Out:
# <i>naive plan: (run <b>LazyFrame.explain(optimized=True)</b> to see the optimized plan)</i>
#     <p></p>
#     <div>DF ["name", "age", "city"]; PROJECT */3 COLUMNS; SELECTION: None</div>

# %%
df
# Out:
# shape: (3, 3)
# ┌─────────┬─────┬─────────────┐
# │ name    ┆ age ┆ city        │
# │ ---     ┆ --- ┆ ---         │
# │ str     ┆ i64 ┆ str         │
# ╞═════════╪═════╪═════════════╡
# │ Alice   ┆ 25  ┆ New York    │
# │ Bob     ┆ 30  ┆ Los Angeles │
# │ Charlie ┆ 35  ┆ Chicago     │
# └─────────┴─────┴─────────────┘

# %%
lazy_df_from_csv = pl.read_csv("events.csv").lazy()
lazy_df_from_csv
# Out:
# <i>naive plan: (run <b>LazyFrame.explain(optimized=True)</b> to see the optimized plan)</i>
#     <p></p>
#     <div>DF ["event_time", "event_type", "product_id", "category_id"]; PROJECT */9 COLUMNS; SELECTION: None</div>

# %%
lazy_df_from_scratch = pl.DataFrame({
"id": [1, 2, 3],
"value": [10, 20, 30]
}).lazy()
lazy_df_from_scratch
# Out:
# <i>naive plan: (run <b>LazyFrame.explain(optimized=True)</b> to see the optimized plan)</i>
#     <p></p>
#     <div>DF ["id", "value"]; PROJECT */2 COLUMNS; SELECTION: None</div>

# %%
result_df = (
pl.scan_csv("events.csv")
.select(['brand', 'event_type', 'price'])
.filter(pl.col('event_type') == 'view')
.group_by("brand").agg([pl.col("price").mean().alias("average_price")])
)
print(result_df)
# Out:
# naive plan: (run LazyFrame.explain(optimized=True) to see the optimized plan)
#
# AGGREGATE
# 	[col("price").mean().alias("average_price")] BY [col("brand")] FROM
#   FILTER [(col("event_type")) == (String(view))] FROM
#      SELECT [col("brand"), col("event_type"), col("price")] FROM
#       Csv SCAN [events.csv]
#       PROJECT */9 COLUMNS

# %%
result_df = (
pl.scan_csv("events.csv")
.select(['brand', 'event_type', 'price'])
.filter(pl.col('event_type') == 'view')
.group_by("brand").agg([pl.col("price").mean().alias("average_price")])
).collect()
print(result_df)
# Out:
# shape: (1_000, 2)
# ┌──────────┬───────────────┐
# │ brand    ┆ average_price │
# │ ---      ┆ ---           │
# │ str      ┆ f64           │
# ╞══════════╪═══════════════╡
# │ dell     ┆ 463.895934    │
# │ dewalt   ┆ 157.344354    │
# │ bosch    ┆ 205.799934    │
# │ imou     ┆ 95.08         │
# │ maxtor   ┆ 72.19         │
# │ …        ┆ …             │
# │ cooler   ┆ 39.321186     │
# │ cello    ┆ 7.945455      │
# │ asustor  ┆ 300.170541    │
# │ delonghi ┆ 568.866806    │
# │ cactus   ┆ 36.854326     │
# └──────────┴───────────────┘

# %%
import polars as pl
lazy_df = pl.scan_csv("events.csv").filter(pl.col("price") > 100)
result_df = lazy_df.collect(streaming=True)
result_df
# Out:
# shape: (345_080, 9)
# ┌──────────────┬────────────┬────────────┬───────────────────┬───┬─────────┬────────┬───────────────────┬──────────────┐
# │ event_time   ┆ event_type ┆ product_id ┆ category_id       ┆ … ┆ brand   ┆ price  ┆ user_id           ┆ user_session │
# │ ---          ┆ ---        ┆ ---        ┆ ---               ┆   ┆ ---     ┆ ---    ┆ ---               ┆ ---          │
# │ str          ┆ str        ┆ i64        ┆ i64               ┆   ┆ str     ┆ f64    ┆ i64               ┆ str          │
# ╞══════════════╪════════════╪════════════╪═══════════════════╪═══╪═════════╪════════╪═══════════════════╪══════════════╡
# │ 2020-09-24   ┆ view       ┆ 635807     ┆ 21444159231072666 ┆ … ┆ pantum  ┆ 113.81 ┆ 15159156255190143 ┆ aGFYrNgC08   │
# │ 11:57:33 UTC ┆            ┆            ┆ 82                ┆   ┆         ┆        ┆ 56                ┆              │
# │ 2020-09-24   ┆ view       ┆ 3791349    ┆ 21444159350861992 ┆ … ┆ null    ┆ 215.41 ┆ 15159156255193888 ┆ J1t6sIYXiV   │
# │ 11:58:23 UTC ┆            ┆            ┆ 25                ┆   ┆         ┆        ┆ 77                ┆              │
# │ 2020-09-24   ┆ view       ┆ 1080093    ┆ 21444159231072666 ┆ … ┆ ricoh   ┆ 268.17 ┆ 15159156255193894 ┆ 63xjTFC54g   │
# │ 12:00:00 UTC ┆            ┆            ┆ 82                ┆   ┆         ┆        ┆ 83                ┆              │
# │ 2020-09-24   ┆ view       ┆ 1455459    ┆ 21444159270499125 ┆ … ┆ sony    ┆ 635.63 ┆ 15159156255193854 ┆ sF2S2yMO09   │
# │ 12:00:01 UTC ┆            ┆            ┆ 42                ┆   ┆         ┆        ┆ 19                ┆              │
# │ 2020-09-24   ┆ view       ┆ 1021484    ┆ 21444159449763683 ┆ … ┆ null    ┆ 202.98 ┆ 15159156255193891 ┆ fO4BG6BTMi   │
# │ 12:00:39 UTC ┆            ┆            ┆ 25                ┆   ┆         ┆        ┆ 01                ┆              │
# │ …            ┆ …          ┆ …          ┆ …                 ┆ … ┆ …       ┆ …      ┆ …                 ┆ …            │
# │ 2021-02-28   ┆ view       ┆ 1271549    ┆ 21444159244242781 ┆ … ┆ edifier ┆ 405.65 ┆ 15159156256110229 ┆ 7geq5gYdXF   │
# │ 23:47:49 UTC ┆            ┆            ┆ 72                ┆   ┆         ┆        ┆ 87                ┆              │
# │ 2021-02-28   ┆ view       ┆ 622796     ┆ 21444159227381679 ┆ … ┆ asus    ┆ 147.38 ┆ 15159156255729475 ┆ LJ4H6CRcME   │
# │ 23:51:25 UTC ┆            ┆            ┆ 21                ┆   ┆         ┆        ┆ 04                ┆              │
# │ 2021-02-28   ┆ view       ┆ 622796     ┆ 21444159227381679 ┆ … ┆ asus    ┆ 147.38 ┆ 15159156255729475 ┆ SqlXaC3Wrw   │
# │ 23:51:25 UTC ┆            ┆            ┆ 21                ┆   ┆         ┆        ┆ 04                ┆              │
# │ 2021-02-28   ┆ view       ┆ 4079420    ┆ 21444159224277894 ┆ … ┆ msi     ┆ 449.51 ┆ 15159156256110235 ┆ zrl0oKrysT   │
# │ 23:53:13 UTC ┆            ┆            ┆ 16                ┆   ┆         ┆        ┆ 81                ┆              │
# │ 2021-02-28   ┆ view       ┆ 953226     ┆ 21444159275532290 ┆ … ┆ null    ┆ 219.94 ┆ 15159156256110237 ┆ FRLqIttxKU   │
# │ 23:55:01 UTC ┆            ┆            ┆ 37                ┆   ┆         ┆        ┆ 30                ┆              │
# └──────────────┴────────────┴────────────┴───────────────────┴───┴─────────┴────────┴───────────────────┴──────────────┘

# %%
# %%timeit
import pandas as pd
df = pd.read_csv("events.csv")
df_selected = df[['brand', 'event_type', 'price']]
df_filtered = df_selected[df_selected['event_type'] == 'view']
result_df = df_filtered.groupby('brand')['price'].mean().reset_index(name='average_price')
print(result_df)
# Out:
#           brand  average_price
# 0        a-data      20.235833
# 1    accesstyle      24.700000
# 2        accord      51.060904
# 3          acct      26.350000
# 4       acecamp      39.553158
# ..          ...            ...
# 994         zmi      61.270000
# 995    zoweetek      35.620000
# 996       zowie      84.577500
# 997         zte      55.175234
# 998       zyxel     207.394491
#
# [999 rows x 2 columns]
#           brand  average_price
# 0        a-data      20.235833
# 1    accesstyle      24.700000
# 2        accord      51.060904
# 3          acct      26.350000
# 4       acecamp      39.553158
# ..          ...            ...
# 994         zmi      61.270000
# 995    zoweetek      35.620000
# 996       zowie      84.577500
# 997         zte      55.175234
# 998       zyxel     207.394491
#
# [999 rows x 2 columns]
#           brand  average_price
# 0        a-data      20.235833
# 1    accesstyle      24.700000
# 2        accord      51.060904
# 3          acct      26.350000
# 4       acecamp      39.553158
# ..          ...            ...
# 994         zmi      61.270000
# 995    zoweetek      35.620000
# 996       zowie      84.577500
# 997         zte      55.175234
# 998       zyxel     207.394491
#
# [999 rows x 2 columns]
#           brand  average_price
# 0        a-data      20.235833
# 1    accesstyle      24.700000
# 2        accord      51.060904
# 3          acct      26.350000
# 4       acecamp      39.553158
# ..          ...            ...
# 994         zmi      61.270000
# 995    zoweetek      35.620000
# 996       zowie      84.577500
# 997         zte      55.175234
# 998       zyxel     207.394491
#
# [999 rows x 2 columns]
#           brand  average_price
# 0        a-data      20.235833
# 1    accesstyle      24.700000
# 2        accord      51.060904
# 3          acct      26.350000
# 4       acecamp      39.553158
# ..          ...            ...
# 994         zmi      61.270000
# 995    zoweetek      35.620000
# 996       zowie      84.577500
# 997         zte      55.175234
# 998       zyxel     207.394491
#
# [999 rows x 2 columns]
#           brand  average_price
# 0        a-data      20.235833
# 1    accesstyle      24.700000
# 2        accord      51.060904
# 3          acct      26.350000
# 4       acecamp      39.553158
# ..          ...            ...
# 994         zmi      61.270000
# 995    zoweetek      35.620000
# 996       zowie      84.577500
# 997         zte      55.175234
# 998       zyxel     207.394491
#
# [999 rows x 2 columns]
#           brand  average_price
# 0        a-data      20.235833
# 1    accesstyle      24.700000
# 2        accord      51.060904
# 3          acct      26.350000
# 4       acecamp      39.553158
# ..          ...            ...
# 994         zmi      61.270000
# 995    zoweetek      35.620000
# 996       zowie      84.577500
# 997         zte      55.175234
# 998       zyxel     207.394491
#
# [999 rows x 2 columns]
#           brand  average_price
# 0        a-data      20.235833
# 1    accesstyle      24.700000
# 2        accord      51.060904
# 3          acct      26.350000
# 4       acecamp      39.553158
# ..          ...            ...
# 994         zmi      61.270000
# 995    zoweetek      35.620000
# 996       zowie      84.577500
# 997         zte      55.175234
# 998       zyxel     207.394491
#
# [999 rows x 2 columns]
# 1.37 s ± 57.2 ms per loop (mean ± std. dev. of 7 runs, 1 loop each)

# %%
# %%timeit
import polars as pl
result_df = (pl.scan_csv("events.csv")
.select(['brand', 'event_type', 'price'])
.filter(pl.col('event_type') == 'view')
.group_by("brand").agg([pl.col("price").mean().alias("average_price")])
).collect()
print(result_df)
# Out:
# shape: (1_000, 2)
# ┌──────────┬───────────────┐
# │ brand    ┆ average_price │
# │ ---      ┆ ---           │
# │ str      ┆ f64           │
# ╞══════════╪═══════════════╡
# │ huter    ┆ 264.027816    │
# │ dell     ┆ 463.895934    │
# │ interos  ┆ 28.32         │
# │ rondell  ┆ 16.93         │
# │ sharp    ┆ 183.596122    │
# │ …        ┆ …             │
# │ pockets  ┆ 6.4           │
# │ megaopt  ┆ 6.080388      │
# │ twinkly  ┆ 203.360934    │
# │ sharkoon ┆ 334.29        │
# │ bresser  ┆ 81.27         │
# └──────────┴───────────────┘
# shape: (1_000, 2)
# ┌─────────────┬───────────────┐
# │ brand       ┆ average_price │
# │ ---         ┆ ---           │
# │ str         ┆ f64           │
# ╞═════════════╪═══════════════╡
# │ tm          ┆ 22.35         │
# │ sceye       ┆ 730.96        │
# │ momax       ┆ 44.856477     │
# │ yihua       ┆ 26.500909     │
# │ ozaki       ┆ 10.48         │
# │ …           ┆ …             │
# │ cyberpower  ┆ 343.68837     │
# │ orient      ┆ 28.364735     │
# │ silverstone ┆ 36.066667     │
# │ seagate     ┆ 123.392427    │
# │ null        ┆ 76.742133     │
# └─────────────┴───────────────┘
# shape: (1_000, 2)
# ┌─────────┬───────────────┐
# │ brand   ┆ average_price │
# │ ---     ┆ ---           │
# │ str     ┆ f64           │
# ╞═════════╪═══════════════╡
# │ davinci ┆ 49.769545     │
# │ skynet  ┆ 67.134762     │
# │ ezviz   ┆ 155.175614    │
# │ lukey   ┆ 74.7425       │
# │ vetus   ┆ 13.95         │
# │ …       ┆ …             │
# │ edge    ┆ 39.844067     │
# │ gaoke   ┆ 432.22        │
# │ sky     ┆ 40.774685     │
# │ knipex  ┆ 54.24         │
# │ saturn  ┆ 47.977333     │
# └─────────┴───────────────┘
# shape: (1_000, 2)
# ┌────────┬───────────────┐
# │ brand  ┆ average_price │
# │ ---    ┆ ---           │
# │ str    ┆ f64           │
# ╞════════╪═══════════════╡
# │ sbs    ┆ 12.345143     │
# │ luphie ┆ 14.29         │
# │ spigen ┆ 23.908255     │
# │ apexto ┆ 20.57         │
# │ vitek  ┆ 26.17         │
# │ …      ┆ …             │
# │ tt     ┆ 26.356        │
# │ irit   ┆ 15.80467      │
# │ iek    ┆ 67.536253     │
# │ diolex ┆ 13.498571     │
# │ romoss ┆ 51.94975      │
# └────────┴───────────────┘
# shape: (1_000, 2)
# ┌────────────┬───────────────┐
# │ brand      ┆ average_price │
# │ ---        ┆ ---           │
# │ str        ┆ f64           │
# ╞════════════╪═══════════════╡
# │ rivacase   ┆ 40.065051     │
# │ apexto     ┆ 20.57         │
# │ oklick     ┆ 26.542551     │
# │ astralux   ┆ 86.97         │
# │ iqfuture   ┆ 21.33475      │
# │ …          ┆ …             │
# │ supermicro ┆ 235.075675    │
# │ fiskars    ┆ 36.72         │
# │ e-blue     ┆ 14.7525       │
# │ ninebot    ┆ 372.35        │
# │ playme     ┆ 143.105857    │
# └────────────┴───────────────┘
# shape: (1_000, 2)
# ┌──────────┬───────────────┐
# │ brand    ┆ average_price │
# │ ---      ┆ ---           │
# │ str      ┆ f64           │
# ╞══════════╪═══════════════╡
# │ fibaro   ┆ 76.03         │
# │ galaxy   ┆ 35.783228     │
# │ top      ┆ 33.330043     │
# │ bosch    ┆ 205.799934    │
# │ fiesta   ┆ 27.145714     │
# │ …        ┆ …             │
# │ urbano   ┆ 85.65         │
# │ gladwork ┆ 124.613059    │
# │ aqc      ┆ 15.450215     │
# │ ipearl   ┆ 32.7          │
# │ saturn   ┆ 47.977333     │
# └──────────┴───────────────┘
# shape: (1_000, 2)
# ┌─────────┬───────────────┐
# │ brand   ┆ average_price │
# │ ---     ┆ ---           │
# │ str     ┆ f64           │
# ╞═════════╪═══════════════╡
# │ laut    ┆ 28.795435     │
# │ pgytech ┆ 32.6          │
# │ phantom ┆ 79.669602     │
# │ komfort ┆ 16.43         │
# │ aqc     ┆ 15.450215     │
# │ …       ┆ …             │
# │ jekod   ┆ 1.57          │
# │ yixing  ┆ 67.575        │
# │ makel   ┆ 13.423871     │
# │ luphie  ┆ 14.29         │
# │ lunatik ┆ 26.83         │
# └─────────┴───────────────┘
# shape: (1_000, 2)
# ┌──────────┬───────────────┐
# │ brand    ┆ average_price │
# │ ---      ┆ ---           │
# │ str      ┆ f64           │
# ╞══════════╪═══════════════╡
# │ melitta  ┆ 727.002317    │
# │ moxom    ┆ 17.56748      │
# │ masters  ┆ 54.915758     │
# │ tt       ┆ 26.356        │
# │ zepter   ┆ 246.87        │
# │ …        ┆ …             │
# │ sparks   ┆ 5.486667      │
# │ revolter ┆ 182.239333    │
# │ itk      ┆ 44.582083     │
# │ promo    ┆ 14.564        │
# │ parlux   ┆ 248.268       │
# └──────────┴───────────────┘
# shape: (1_000, 2)
# ┌─────────┬───────────────┐
# │ brand   ┆ average_price │
# │ ---     ┆ ---           │
# │ str     ┆ f64           │
# ╞═════════╪═══════════════╡
# │ jet     ┆ 87.785684     │
# │ arctic  ┆ 46.978889     │
# │ delta   ┆ 39.764845     │
# │ iboto   ┆ 294.236571    │
# │ skynet  ┆ 67.134762     │
# │ …       ┆ …             │
# │ osram   ┆ 4.578         │
# │ tefal   ┆ 155.370672    │
# │ orient  ┆ 28.364735     │
# │ twinkly ┆ 203.360934    │
# │ alfa    ┆ 36.857008     │
# └─────────┴───────────────┘
# shape: (1_000, 2)
# ┌───────────┬───────────────┐
# │ brand     ┆ average_price │
# │ ---       ┆ ---           │
# │ str       ┆ f64           │
# ╞═══════════╪═══════════════╡
# │ cet       ┆ 34.60883      │
# │ maxcut    ┆ 65.6          │
# │ deppa     ┆ 13.732737     │
# │ synology  ┆ 397.418846    │
# │ universal ┆ 32.40589      │
# │ …         ┆ …             │
# │ jakemy    ┆ 18.005        │
# │ wiwu      ┆ 33.245658     │
# │ joyroom   ┆ 40.855077     │
# │ bakon     ┆ 51.75         │
# │ in        ┆ 72.3928       │
# └───────────┴───────────────┘
# shape: (1_000, 2)
# ┌──────────┬───────────────┐
# │ brand    ┆ average_price │
# │ ---      ┆ ---           │
# │ str      ┆ f64           │
# ╞══════════╪═══════════════╡
# │ redragon ┆ 43.989874     │
# │ romoss   ┆ 51.94975      │
# │ baku     ┆ 13.164634     │
# │ infocus  ┆ 445.735       │
# │ msi      ┆ 360.718335    │
# │ …        ┆ …             │
# │ rubetek  ┆ 210.720455    │
# │ celly    ┆ 10.973127     │
# │ klevv    ┆ 57.914        │
# │ beko     ┆ 175.4036      │
# │ elp      ┆ 16.097236     │
# └──────────┴───────────────┘
# shape: (1_000, 2)
# ┌─────────────┬───────────────┐
# │ brand       ┆ average_price │
# │ ---         ┆ ---           │
# │ str         ┆ f64           │
# ╞═════════════╪═══════════════╡
# │ hyperdrive  ┆ 93.272        │
# │ piquadro    ┆ 500.872692    │
# │ amega       ┆ 111.843014    │
# │ ninebot     ┆ 372.35        │
# │ oltramax    ┆ 11.93377      │
# │ …           ┆ …             │
# │ ibox        ┆ 8.620855      │
# │ forward     ┆ 24.935532     │
# │ acorp       ┆ 14.75         │
# │ thermaltake ┆ 103.063556    │
# │ ballistix   ┆ 69.510321     │
# └─────────────┴───────────────┘
# shape: (1_000, 2)
# ┌────────────┬───────────────┐
# │ brand      ┆ average_price │
# │ ---        ┆ ---           │
# │ str        ┆ f64           │
# ╞════════════╪═══════════════╡
# │ winard     ┆ 28.903594     │
# │ remax      ┆ 25.267401     │
# │ mercury    ┆ 24.506197     │
# │ neomax     ┆ 59.907347     │
# │ chieftec   ┆ 78.247412     │
# │ …          ┆ …             │
# │ ecola      ┆ 11.480763     │
# │ ballet     ┆ 13.37         │
# │ optimus    ┆ 73.44875      │
# │ accesstyle ┆ 24.7          │
# │ seagate    ┆ 123.392427    │
# └────────────┴───────────────┘
# shape: (1_000, 2)
# ┌─────────────┬───────────────┐
# │ brand       ┆ average_price │
# │ ---         ┆ ---           │
# │ str         ┆ f64           │
# ╞═════════════╪═══════════════╡
# │ soundstream ┆ 110.436914    │
# │ msi         ┆ 360.718335    │
# │ amazfit     ┆ 122.843544    │
# │ iconik      ┆ 13.724286     │
# │ dialog      ┆ 62.805993     │
# │ …           ┆ …             │
# │ galanz      ┆ 133.16        │
# │ samsung     ┆ 223.506667    │
# │ top         ┆ 33.330043     │
# │ raidmax     ┆ 71.698889     │
# │ maunfeld    ┆ 222.418125    │
# └─────────────┴───────────────┘
# shape: (1_000, 2)
# ┌───────────┬───────────────┐
# │ brand     ┆ average_price │
# │ ---       ┆ ---           │
# │ str       ┆ f64           │
# ╞═══════════╪═══════════════╡
# │ zebra     ┆ 76.552234     │
# │ dyp       ┆ 10.779412     │
# │ icasemore ┆ 11.029615     │
# │ kivi      ┆ 284.668158    │
# │ alas      ┆ 32.25438      │
# │ …         ┆ …             │
# │ cipherlab ┆ 95.25         │
# │ trassir   ┆ 333.180952    │
# │ romoss    ┆ 51.94975      │
# │ janome    ┆ 275.160666    │
# │ dji       ┆ 828.885809    │
# └───────────┴───────────────┘
# shape: (1_000, 2)
# ┌───────────┬───────────────┐
# │ brand     ┆ average_price │
# │ ---       ┆ ---           │
# │ str       ┆ f64           │
# ╞═══════════╪═══════════════╡
# │ yoobao    ┆ 29.16         │
# │ avision   ┆ 758.54641     │
# │ itk       ┆ 44.582083     │
# │ alfa      ┆ 36.857008     │
# │ inktec    ┆ 7.273333      │
# │ …         ┆ …             │
# │ da        ┆ 19.144        │
# │ smarterra ┆ 27.814922     │
# │ singer    ┆ 190.546958    │
# │ gembird   ┆ 16.438899     │
# │ fanvil    ┆ 49.0935       │
# └───────────┴───────────────┘
# shape: (1_000, 2)
# ┌───────────────────┬───────────────┐
# │ brand             ┆ average_price │
# │ ---               ┆ ---           │
# │ str               ┆ f64           │
# ╞═══════════════════╪═══════════════╡
# │ polaroid          ┆ 9.14          │
# │ spigen            ┆ 23.908255     │
# │ victorinox        ┆ 84.103632     │
# │ electronicsdeluxe ┆ 198.023793    │
# │ gefest            ┆ 163.028904    │
# │ …                 ┆ …             │
# │ inktec            ┆ 7.273333      │
# │ elp               ┆ 16.097236     │
# │ geha              ┆ 46.645        │
# │ engenius          ┆ 180.689375    │
# │ nobby             ┆ 37.239444     │
# └───────────────────┴───────────────┘
# shape: (1_000, 2)
# ┌────────────┬───────────────┐
# │ brand      ┆ average_price │
# │ ---        ┆ ---           │
# │ str        ┆ f64           │
# ╞════════════╪═══════════════╡
# │ remington  ┆ 76.648571     │
# │ navan      ┆ 26.844054     │
# │ thermos    ┆ 63.891588     │
# │ meizu      ┆ 61.709783     │
# │ lenovo     ┆ 120.130594    │
# │ …          ┆ …             │
# │ rotring    ┆ 21.84614      │
# │ rexel      ┆ 439.068868    │
# │ scher-khan ┆ 106.197805    │
# │ haier      ┆ 83.742109     │
# │ gigaset    ┆ 80.462577     │
# └────────────┴───────────────┘
# shape: (1_000, 2)
# ┌────────────┬───────────────┐
# │ brand      ┆ average_price │
# │ ---        ┆ ---           │
# │ str        ┆ f64           │
# ╞════════════╪═══════════════╡
# │ coteetci   ┆ 38.264441     │
# │ mallony    ┆ 14.894091     │
# │ zeon       ┆ 44.566667     │
# │ iconbit    ┆ 27.54         │
# │ id-cooling ┆ 29.731698     │
# │ …          ┆ …             │
# │ arian      ┆ 47.622323     │
# │ aerocool   ┆ 70.834226     │
# │ foxweld    ┆ 62.637778     │
# │ aqc        ┆ 15.450215     │
# │ jonnesway  ┆ 176.038066    │
# └────────────┴───────────────┘
# shape: (1_000, 2)
# ┌───────────┬───────────────┐
# │ brand     ┆ average_price │
# │ ---       ┆ ---           │
# │ str       ┆ f64           │
# ╞═══════════╪═══════════════╡
# │ moxom     ┆ 17.56748      │
# │ tt        ┆ 26.356        │
# │ dremel    ┆ 83.437907     │
# │ lexand    ┆ 68.807        │
# │ bbk       ┆ 115.02663     │
# │ …         ┆ …             │
# │ smarterra ┆ 27.814922     │
# │ heddy     ┆ 20.354186     │
# │ brita     ┆ 21.9225       │
# │ baseus    ┆ 25.661166     │
# │ zalman    ┆ 56.258163     │
# └───────────┴───────────────┘
# shape: (1_000, 2)
# ┌──────────┬───────────────┐
# │ brand    ┆ average_price │
# │ ---      ┆ ---           │
# │ str      ┆ f64           │
# ╞══════════╪═══════════════╡
# │ hiwatch  ┆ 119.408657    │
# │ borofone ┆ 16.050478     │
# │ bion     ┆ 16.896802     │
# │ maxtor   ┆ 72.19         │
# │ aukey    ┆ 34.697556     │
# │ …        ┆ …             │
# │ defender ┆ 29.724627     │
# │ elekta   ┆ 20.22         │
# │ p.i.t.   ┆ 76.269172     │
# │ tantos   ┆ 102.039714    │
# │ spigen   ┆ 23.908255     │
# └──────────┴───────────────┘
# shape: (1_000, 2)
# ┌───────────┬───────────────┐
# │ brand     ┆ average_price │
# │ ---       ┆ ---           │
# │ str       ┆ f64           │
# ╞═══════════╪═══════════════╡
# │ uragan    ┆ 11.961429     │
# │ autobot   ┆ 16.83         │
# │ itk       ┆ 44.582083     │
# │ mcdodo    ┆ 31.610714     │
# │ maono     ┆ 44.929639     │
# │ …         ┆ …             │
# │ denon     ┆ 332.497329    │
# │ acmepower ┆ 22.246818     │
# │ beecaro   ┆ 30.16         │
# │ arctic    ┆ 46.978889     │
# │ paprcuts  ┆ 8.152         │
# └───────────┴───────────────┘
# shape: (1_000, 2)
# ┌────────────┬───────────────┐
# │ brand      ┆ average_price │
# │ ---        ┆ ---           │
# │ str        ┆ f64           │
# ╞════════════╪═══════════════╡
# │ p.i.t.     ┆ 76.269172     │
# │ plextor    ┆ 86.709643     │
# │ oce        ┆ 27.0175       │
# │ intex      ┆ 17.43         │
# │ monsterpad ┆ 95.772105     │
# │ …          ┆ …             │
# │ wits       ┆ 16.486061     │
# │ redmi      ┆ 198.367818    │
# │ delux      ┆ 10.87         │
# │ alligator  ┆ 86.294615     │
# │ telefunken ┆ 80.066957     │
# └────────────┴───────────────┘
# shape: (1_000, 2)
# ┌──────────┬───────────────┐
# │ brand    ┆ average_price │
# │ ---      ┆ ---           │
# │ str      ┆ f64           │
# ╞══════════╪═══════════════╡
# │ pero     ┆ 10.62         │
# │ vstarcam ┆ 84.206667     │
# │ winard   ┆ 28.903594     │
# │ rexant   ┆ 21.636772     │
# │ gp       ┆ 15.214468     │
# │ …        ┆ …             │
# │ magnit   ┆ 46.03386      │
# │ hp       ┆ 161.0114      │
# │ twt      ┆ 11.072093     │
# │ hpe      ┆ 911.890145    │
# │ nillkin  ┆ 20.0          │
# └──────────┴───────────────┘
# shape: (1_000, 2)
# ┌────────────┬───────────────┐
# │ brand      ┆ average_price │
# │ ---        ┆ ---           │
# │ str        ┆ f64           │
# ╞════════════╪═══════════════╡
# │ blast      ┆ 28.129181     │
# │ karcher    ┆ 264.27045     │
# │ pilot      ┆ 22.759674     │
# │ asahi      ┆ 40.63         │
# │ bayerhoff  ┆ 24.33         │
# │ …          ┆ …             │
# │ thomas     ┆ 298.980634    │
# │ foxconn    ┆ 29.81         │
# │ olto       ┆ 83.516923     │
# │ sennheiser ┆ 59.548027     │
# │ mercusys   ┆ 22.805312     │
# └────────────┴───────────────┘
# shape: (1_000, 2)
# ┌─────────────┬───────────────┐
# │ brand       ┆ average_price │
# │ ---         ┆ ---           │
# │ str         ┆ f64           │
# ╞═════════════╪═══════════════╡
# │ cameronsino ┆ 24.564187     │
# │ celly       ┆ 10.973127     │
# │ kromax      ┆ 34.300348     │
# │ bion        ┆ 16.896802     │
# │ haier       ┆ 83.742109     │
# │ …           ┆ …             │
# │ grinda      ┆ 24.741622     │
# │ hyperjuice  ┆ 21.59         │
# │ fit         ┆ 26.839312     │
# │ starline    ┆ 110.324       │
# │ college     ┆ 103.785385    │
# └─────────────┴───────────────┘
# shape: (1_000, 2)
# ┌───────────┬───────────────┐
# │ brand     ┆ average_price │
# │ ---       ┆ ---           │
# │ str       ┆ f64           │
# ╞═══════════╪═══════════════╡
# │ greys     ┆ 64.644564     │
# │ vari      ┆ 22.7312       │
# │ alfa      ┆ 36.857008     │
# │ ozone     ┆ 36.752083     │
# │ seagate   ┆ 123.392427    │
# │ …         ┆ …             │
# │ euroflex  ┆ 66.83         │
# │ borofone  ┆ 16.050478     │
# │ galanz    ┆ 133.16        │
# │ apacer    ┆ 45.104809     │
# │ prestigio ┆ 85.161182     │
# └───────────┴───────────────┘
# shape: (1_000, 2)
# ┌────────────┬───────────────┐
# │ brand      ┆ average_price │
# │ ---        ┆ ---           │
# │ str        ┆ f64           │
# ╞════════════╪═══════════════╡
# │ thinmax    ┆ 13.81         │
# │ alphachem  ┆ 11.52         │
# │ spl        ┆ 192.3775      │
# │ mobility   ┆ 12.911667     │
# │ switcheasy ┆ 32.7          │
# │ …          ┆ …             │
# │ lomond     ┆ 23.231647     │
# │ sunpro     ┆ 30.37         │
# │ hikvision  ┆ 198.666012    │
# │ max        ┆ 40.749737     │
# │ keter      ┆ 77.63         │
# └────────────┴───────────────┘
# shape: (1_000, 2)
# ┌──────────┬───────────────┐
# │ brand    ┆ average_price │
# │ ---      ┆ ---           │
# │ str      ┆ f64           │
# ╞══════════╪═══════════════╡
# │ geil     ┆ 83.0          │
# │ mobilepc ┆ 26.351757     │
# │ iconbit  ┆ 27.54         │
# │ outdoor  ┆ 29.37         │
# │ portcase ┆ 34.104513     │
# │ …        ┆ …             │
# │ tranking ┆ 14.4          │
# │ digoldy  ┆ 11.9175       │
# │ lexand   ┆ 68.807        │
# │ sven     ┆ 61.518469     │
# │ jakemy   ┆ 18.005        │
# └──────────┴───────────────┘
# shape: (1_000, 2)
# ┌──────────────────┬───────────────┐
# │ brand            ┆ average_price │
# │ ---              ┆ ---           │
# │ str              ┆ f64           │
# ╞══════════════════╪═══════════════╡
# │ yealink          ┆ 253.17675     │
# │ vigilant         ┆ 67.27         │
# │ noreve           ┆ 1.57          │
# │ msi              ┆ 360.718335    │
# │ pilotage         ┆ 56.20174      │
# │ …                ┆ …             │
# │ ginzzu           ┆ 60.383349     │
# │ uniq             ┆ 24.193704     │
# │ hotpoint-ariston ┆ 324.801702    │
# │ komfort          ┆ 16.43         │
# │ pgytech          ┆ 32.6          │
# └──────────────────┴───────────────┘
# shape: (1_000, 2)
# ┌──────────┬───────────────┐
# │ brand    ┆ average_price │
# │ ---      ┆ ---           │
# │ str      ┆ f64           │
# ╞══════════╪═══════════════╡
# │ upvel    ┆ 41.045806     │
# │ levenhuk ┆ 58.652809     │
# │ gigalink ┆ 33.992308     │
# │ gbc      ┆ 267.025283    │
# │ patriot  ┆ 303.95553     │
# │ …        ┆ …             │
# │ thomson  ┆ 21.171463     │
# │ canon    ┆ 150.605848    │
# │ zmi      ┆ 61.27         │
# │ thronmax ┆ 121.825556    │
# │ fubag    ┆ 126.090675    │
# └──────────┴───────────────┘
# shape: (1_000, 2)
# ┌────────────┬───────────────┐
# │ brand      ┆ average_price │
# │ ---        ┆ ---           │
# │ str        ┆ f64           │
# ╞════════════╪═══════════════╡
# │ xp-pen     ┆ 93.639792     │
# │ imou       ┆ 95.08         │
# │ filtero    ┆ 7.96          │
# │ snr        ┆ 77.08         │
# │ mustek     ┆ 129.5288      │
# │ …          ┆ …             │
# │ jonnesway  ┆ 176.038066    │
# │ coteetci   ┆ 38.264441     │
# │ hyundai    ┆ 102.951649    │
# │ intro      ┆ 317.536338    │
# │ interpower ┆ 21.986431     │
# └────────────┴───────────────┘
# shape: (1_000, 2)
# ┌────────────┬───────────────┐
# │ brand      ┆ average_price │
# │ ---        ┆ ---           │
# │ str        ┆ f64           │
# ╞════════════╪═══════════════╡
# │ hanskonner ┆ 49.217576     │
# │ sanitas    ┆ 64.469        │
# │ syma       ┆ 71.583113     │
# │ moodo      ┆ 172.54        │
# │ nokia      ┆ 93.813072     │
# │ …          ┆ …             │
# │ nv-print   ┆ 19.782686     │
# │ tefal      ┆ 155.370672    │
# │ qumo       ┆ 25.182509     │
# │ akel       ┆ 58.732        │
# │ vstarcam   ┆ 84.206667     │
# └────────────┴───────────────┘
# shape: (1_000, 2)
# ┌────────────┬───────────────┐
# │ brand      ┆ average_price │
# │ ---        ┆ ---           │
# │ str        ┆ f64           │
# ╞════════════╪═══════════════╡
# │ lp         ┆ 12.38         │
# │ ldnio      ┆ 21.793659     │
# │ filtero    ┆ 7.96          │
# │ cenmax     ┆ 66.071346     │
# │ ninebot    ┆ 372.35        │
# │ …          ┆ …             │
# │ kraftmark  ┆ 35.976364     │
# │ willmark   ┆ 35.452143     │
# │ auchan     ┆ 1019.095789   │
# │ smarttools ┆ 30.95         │
# │ enermax    ┆ 161.444286    │
# └────────────┴───────────────┘
# shape: (1_000, 2)
# ┌───────────┬───────────────┐
# │ brand     ┆ average_price │
# │ ---       ┆ ---           │
# │ str       ┆ f64           │
# ╞═══════════╪═══════════════╡
# │ campingaz ┆ 57.1825       │
# │ dewalt    ┆ 157.344354    │
# │ printpro  ┆ 8.57902       │
# │ p.i.t.    ┆ 76.269172     │
# │ thermos   ┆ 63.891588     │
# │ …         ┆ …             │
# │ oukitel   ┆ 182.671667    │
# │ exployd   ┆ 13.042098     │
# │ infocus   ┆ 445.735       │
# │ nikon     ┆ 793.346586    │
# │ element   ┆ 56.707267     │
# └───────────┴───────────────┘
# shape: (1_000, 2)
# ┌──────────┬───────────────┐
# │ brand    ┆ average_price │
# │ ---      ┆ ---           │
# │ str      ┆ f64           │
# ╞══════════╪═══════════════╡
# │ geil     ┆ 83.0          │
# │ and      ┆ 34.725051     │
# │ oxion    ┆ 10.231379     │
# │ morel    ┆ 107.14809     │
# │ midea    ┆ 87.766593     │
# │ …        ┆ …             │
# │ dremel   ┆ 83.437907     │
# │ college  ┆ 103.785385    │
# │ inktec   ┆ 7.273333      │
# │ marvo    ┆ 29.32         │
# │ vstarcam ┆ 84.206667     │
# └──────────┴───────────────┘
# shape: (1_000, 2)
# ┌───────────┬───────────────┐
# │ brand     ┆ average_price │
# │ ---       ┆ ---           │
# │ str       ┆ f64           │
# ╞═══════════╪═══════════════╡
# │ autobot   ┆ 16.83         │
# │ max       ┆ 40.749737     │
# │ steel     ┆ 8.61          │
# │ meizu     ┆ 61.709783     │
# │ hyperx    ┆ 89.155553     │
# │ …         ┆ …             │
# │ tiger     ┆ 49.818        │
# │ avision   ┆ 758.54641     │
# │ komfort   ┆ 16.43         │
# │ autoprofi ┆ 39.22         │
# │ oukitel   ┆ 182.671667    │
# └───────────┴───────────────┘
# shape: (1_000, 2)
# ┌───────────┬───────────────┐
# │ brand     ┆ average_price │
# │ ---       ┆ ---           │
# │ str       ┆ f64           │
# ╞═══════════╪═══════════════╡
# │ inspector ┆ 151.395023    │
# │ keenetic  ┆ 122.175464    │
# │ neoclima  ┆ 102.043846    │
# │ coolpad   ┆ 89.84         │
# │ stlab     ┆ 47.41         │
# │ …         ┆ …             │
# │ belsis    ┆ 10.402        │
# │ iconik    ┆ 13.724286     │
# │ exegate   ┆ 34.3517       │
# │ magner    ┆ 1554.44       │
# │ winard    ┆ 28.903594     │
# └───────────┴───────────────┘
# shape: (1_000, 2)
# ┌────────────┬───────────────┐
# │ brand      ┆ average_price │
# │ ---        ┆ ---           │
# │ str        ┆ f64           │
# ╞════════════╪═══════════════╡
# │ ipega      ┆ 27.892139     │
# │ citizen    ┆ 18.991087     │
# │ ismartdigi ┆ 16.413837     │
# │ ganzo      ┆ 46.98         │
# │ singer     ┆ 190.546958    │
# │ …          ┆ …             │
# │ bakon      ┆ 51.75         │
# │ null       ┆ 76.742133     │
# │ ultraflash ┆ 15.830068     │
# │ boneco     ┆ 244.32        │
# │ beats      ┆ 186.0024      │
# └────────────┴───────────────┘
# shape: (1_000, 2)
# ┌───────────┬───────────────┐
# │ brand     ┆ average_price │
# │ ---       ┆ ---           │
# │ str       ┆ f64           │
# ╞═══════════╪═══════════════╡
# │ melitta   ┆ 727.002317    │
# │ jpn       ┆ 56.026531     │
# │ huter     ┆ 264.027816    │
# │ casual    ┆ 12.73         │
# │ uragan    ┆ 11.961429     │
# │ …         ┆ …             │
# │ gorenje   ┆ 164.993372    │
# │ giaretti  ┆ 9.945         │
# │ optoma    ┆ 514.251235    │
# │ allocacoc ┆ 26.368539     │
# │ nokia     ┆ 93.813072     │
# └───────────┴───────────────┘
# shape: (1_000, 2)
# ┌────────────┬───────────────┐
# │ brand      ┆ average_price │
# │ ---        ┆ ---           │
# │ str        ┆ f64           │
# ╞════════════╪═══════════════╡
# │ zencha     ┆ 22.6          │
# │ stlab      ┆ 47.41         │
# │ ultraflash ┆ 15.830068     │
# │ gfgril     ┆ 130.350108    │
# │ cybertek   ┆ 20.22         │
# │ …          ┆ …             │
# │ yison      ┆ 28.89         │
# │ wwq        ┆ 29.86         │
# │ mcdodo     ┆ 31.610714     │
# │ craftmann  ┆ 14.445        │
# │ leomax     ┆ 15.05         │
# └────────────┴───────────────┘
# shape: (1_000, 2)
# ┌────────────┬───────────────┐
# │ brand      ┆ average_price │
# │ ---        ┆ ---           │
# │ str        ┆ f64           │
# ╞════════════╪═══════════════╡
# │ polaris    ┆ 71.938672     │
# │ jbl        ┆ 92.163415     │
# │ eva        ┆ 21.894354     │
# │ maxwell    ┆ 16.03         │
# │ saitek     ┆ 155.1         │
# │ …          ┆ …             │
# │ nikon      ┆ 793.346586    │
# │ rovermate  ┆ 25.79         │
# │ sennheiser ┆ 59.548027     │
# │ playme     ┆ 143.105857    │
# │ trust      ┆ 57.787517     │
# └────────────┴───────────────┘
# shape: (1_000, 2)
# ┌──────────┬───────────────┐
# │ brand    ┆ average_price │
# │ ---      ┆ ---           │
# │ str      ┆ f64           │
# ╞══════════╪═══════════════╡
# │ procase  ┆ 94.738774     │
# │ koowheel ┆ 399.329114    │
# │ lp       ┆ 12.38         │
# │ tomahawk ┆ 61.585725     │
# │ sven     ┆ 61.518469     │
# │ …        ┆ …             │
# │ kyocera  ┆ 388.54021     │
# │ hideit   ┆ 53.17         │
# │ mxq      ┆ 29.430508     │
# │ zte      ┆ 55.175234     │
# │ rotring  ┆ 21.84614      │
# └──────────┴───────────────┘
# shape: (1_000, 2)
# ┌──────────┬───────────────┐
# │ brand    ┆ average_price │
# │ ---      ┆ ---           │
# │ str      ┆ f64           │
# ╞══════════╪═══════════════╡
# │ uniq     ┆ 24.193704     │
# │ fubag    ┆ 126.090675    │
# │ g-case   ┆ 13.49         │
# │ mystery  ┆ 45.769719     │
# │ indesit  ┆ 219.272778    │
# │ …        ┆ …             │
# │ mobest   ┆ 13.97         │
# │ tiger    ┆ 49.818        │
# │ videovox ┆ 24.13         │
# │ acv      ┆ 72.416353     │
# │ portcase ┆ 34.104513     │
# └──────────┴───────────────┘
# shape: (1_000, 2)
# ┌────────────┬───────────────┐
# │ brand      ┆ average_price │
# │ ---        ┆ ---           │
# │ str        ┆ f64           │
# ╞════════════╪═══════════════╡
# │ activecam  ┆ 22.54         │
# │ wuw        ┆ 20.63         │
# │ beward     ┆ 14.92         │
# │ phantom    ┆ 79.669602     │
# │ iboto      ┆ 294.236571    │
# │ …          ┆ …             │
# │ akenori    ┆ 145.86        │
# │ jisoncase  ┆ 26.279412     │
# │ crown      ┆ 33.169103     │
# │ electrolux ┆ 97.535385     │
# │ thomson    ┆ 21.171463     │
# └────────────┴───────────────┘
# shape: (1_000, 2)
# ┌────────────┬───────────────┐
# │ brand      ┆ average_price │
# │ ---        ┆ ---           │
# │ str        ┆ f64           │
# ╞════════════╪═══════════════╡
# │ delta      ┆ 39.764845     │
# │ solins     ┆ 14.995657     │
# │ wiiix      ┆ 13.0452       │
# │ powercolor ┆ 361.935772    │
# │ baseus     ┆ 25.661166     │
# │ …          ┆ …             │
# │ supra      ┆ 131.938565    │
# │ iconik     ┆ 13.724286     │
# │ wk         ┆ 21.475009     │
# │ sago       ┆ 15.26         │
# │ svetocopy  ┆ 15.278599     │
# └────────────┴───────────────┘
# shape: (1_000, 2)
# ┌─────────────┬───────────────┐
# │ brand       ┆ average_price │
# │ ---         ┆ ---           │
# │ str         ┆ f64           │
# ╞═════════════╪═══════════════╡
# │ goot        ┆ 18.918361     │
# │ comfort     ┆ 137.521318    │
# │ aukey       ┆ 34.697556     │
# │ vitek       ┆ 26.17         │
# │ marshall    ┆ 186.220556    │
# │ …           ┆ …             │
# │ accord      ┆ 51.060904     │
# │ caterpillar ┆ 59.38         │
# │ gigabyte    ┆ 319.907644    │
# │ g-case      ┆ 13.49         │
# │ solder      ┆ 32.98         │
# └─────────────┴───────────────┘
# shape: (1_000, 2)
# ┌─────────────┬───────────────┐
# │ brand       ┆ average_price │
# │ ---         ┆ ---           │
# │ str         ┆ f64           │
# ╞═════════════╪═══════════════╡
# │ lugaabrasiv ┆ 9.618333      │
# │ xtrememac   ┆ 40.63         │
# │ gladwork    ┆ 124.613059    │
# │ riva        ┆ 22.327949     │
# │ microlife   ┆ 46.467246     │
# │ …           ┆ …             │
# │ neoline     ┆ 209.928587    │
# │ saeco       ┆ 1032.30129    │
# │ piquadro    ┆ 500.872692    │
# │ araree      ┆ 14.468854     │
# │ a-data      ┆ 20.235833     │
# └─────────────┴───────────────┘
# shape: (1_000, 2)
# ┌───────────┬───────────────┐
# │ brand     ┆ average_price │
# │ ---       ┆ ---           │
# │ str       ┆ f64           │
# ╞═══════════╪═══════════════╡
# │ nv-print  ┆ 19.782686     │
# │ zencha    ┆ 22.6          │
# │ powercase ┆ 39.1775       │
# │ trust     ┆ 57.787517     │
# │ lucia     ┆ 47.426289     │
# │ …         ┆ …             │
# │ titan     ┆ 31.702368     │
# │ oukitel   ┆ 182.671667    │
# │ jisoncase ┆ 26.279412     │
# │ wester    ┆ 125.070571    │
# │ maono     ┆ 44.929639     │
# └───────────┴───────────────┘
# shape: (1_000, 2)
# ┌──────────────┬───────────────┐
# │ brand        ┆ average_price │
# │ ---          ┆ ---           │
# │ str          ┆ f64           │
# ╞══════════════╪═══════════════╡
# │ titan        ┆ 31.702368     │
# │ hyperx       ┆ 89.155553     │
# │ cougar       ┆ 76.809967     │
# │ rekam        ┆ 56.113913     │
# │ btcdigger    ┆ 136.03        │
# │ …            ┆ …             │
# │ skymoto      ┆ 72.38         │
# │ null         ┆ 76.742133     │
# │ ionich       ┆ 10.392353     │
# │ battleground ┆ 20.871        │
# │ yaxun        ┆ 19.90331      │
# └──────────────┴───────────────┘
# shape: (1_000, 2)
# ┌─────────────┬───────────────┐
# │ brand       ┆ average_price │
# │ ---         ┆ ---           │
# │ str         ┆ f64           │
# ╞═════════════╪═══════════════╡
# │ engenius    ┆ 180.689375    │
# │ netproduct  ┆ 16.509065     │
# │ carrefour   ┆ 12.86         │
# │ coroplast   ┆ 12.7          │
# │ grandstream ┆ 172.700222    │
# │ …           ┆ …             │
# │ keenetic    ┆ 122.175464    │
# │ gauss       ┆ 13.5235       │
# │ wharfedale  ┆ 101.05        │
# │ null        ┆ 76.742133     │
# │ foxweld     ┆ 62.637778     │
# └─────────────┴───────────────┘
# shape: (1_000, 2)
# ┌─────────────┬───────────────┐
# │ brand       ┆ average_price │
# │ ---         ┆ ---           │
# │ str         ┆ f64           │
# ╞═════════════╪═══════════════╡
# │ jxd         ┆ 67.878989     │
# │ lamirel     ┆ 9.611667      │
# │ galaxy      ┆ 35.783228     │
# │ magistr     ┆ 14.023143     │
# │ polaris     ┆ 71.938672     │
# │ …           ┆ …             │
# │ nakamichi   ┆ 54.29         │
# │ agestar     ┆ 40.837091     │
# │ procase     ┆ 94.738774     │
# │ park        ┆ 7.3275        │
# │ caterpillar ┆ 59.38         │
# └─────────────┴───────────────┘
# shape: (1_000, 2)
# ┌────────────┬───────────────┐
# │ brand      ┆ average_price │
# │ ---        ┆ ---           │
# │ str        ┆ f64           │
# ╞════════════╪═══════════════╡
# │ syma       ┆ 71.583113     │
# │ neoclima   ┆ 102.043846    │
# │ scher-khan ┆ 106.197805    │
# │ crucial    ┆ 56.023995     │
# │ college    ┆ 103.785385    │
# │ …          ┆ …             │
# │ koowheel   ┆ 399.329114    │
# │ wk         ┆ 21.475009     │
# │ eurolux    ┆ 59.436636     │
# │ fanvil     ┆ 49.0935       │
# │ leonord    ┆ 21.87         │
# └────────────┴───────────────┘
# shape: (1_000, 2)
# ┌─────────────────┬───────────────┐
# │ brand           ┆ average_price │
# │ ---             ┆ ---           │
# │ str             ┆ f64           │
# ╞═════════════════╪═══════════════╡
# │ mobest          ┆ 13.97         │
# │ remax           ┆ 25.267401     │
# │ fiskars         ┆ 36.72         │
# │ rapoo           ┆ 34.871766     │
# │ coocazoo        ┆ 78.653263     │
# │ …               ┆ …             │
# │ anker           ┆ 34.03         │
# │ leeco           ┆ 107.332626    │
# │ masters         ┆ 54.915758     │
# │ luminarte       ┆ 92.92         │
# │ fujitsu-siemens ┆ 716.748519    │
# └─────────────────┴───────────────┘
# shape: (1_000, 2)
# ┌──────────┬───────────────┐
# │ brand    ┆ average_price │
# │ ---      ┆ ---           │
# │ str      ┆ f64           │
# ╞══════════╪═══════════════╡
# │ boyscout ┆ 12.776        │
# │ magnit   ┆ 46.03386      │
# │ sony     ┆ 393.285893    │
# │ asus     ┆ 236.43034     │
# │ sunpro   ┆ 30.37         │
# │ …        ┆ …             │
# │ tesla    ┆ 57.24         │
# │ pilotage ┆ 56.20174      │
# │ optima   ┆ 33.61         │
# │ college  ┆ 103.785385    │
# │ hiwatch  ┆ 119.408657    │
# └──────────┴───────────────┘
# shape: (1_000, 2)
# ┌──────────┬───────────────┐
# │ brand    ┆ average_price │
# │ ---      ┆ ---           │
# │ str      ┆ f64           │
# ╞══════════╪═══════════════╡
# │ isa      ┆ 16.62         │
# │ rolsen   ┆ 37.62         │
# │ pmma     ┆ 9.300394      │
# │ polaroid ┆ 9.14          │
# │ lsi      ┆ 631.137       │
# │ …        ┆ …             │
# │ dolmer   ┆ 18.76         │
# │ geil     ┆ 83.0          │
# │ elari    ┆ 60.084255     │
# │ enermax  ┆ 161.444286    │
# │ kes      ┆ 7.27          │
# └──────────┴───────────────┘
# shape: (1_000, 2)
# ┌─────────────┬───────────────┐
# │ brand       ┆ average_price │
# │ ---         ┆ ---           │
# │ str         ┆ f64           │
# ╞═════════════╪═══════════════╡
# │ ivon        ┆ 15.71         │
# │ lighthouse  ┆ 26.743333     │
# │ mallony     ┆ 14.894091     │
# │ netis       ┆ 29.442542     │
# │ positive    ┆ 11.769848     │
# │ …           ┆ …             │
# │ euroflex    ┆ 66.83         │
# │ proda       ┆ 21.745455     │
# │ romix       ┆ 17.815        │
# │ plantronics ┆ 81.022047     │
# │ quantoom    ┆ 25.373548     │
# └─────────────┴───────────────┘
# shape: (1_000, 2)
# ┌────────────┬───────────────┐
# │ brand      ┆ average_price │
# │ ---        ┆ ---           │
# │ str        ┆ f64           │
# ╞════════════╪═══════════════╡
# │ smtt       ┆ 10.373409     │
# │ wahl       ┆ 55.573684     │
# │ polaris    ┆ 71.938672     │
# │ lumiix     ┆ 4.71          │
# │ yihua      ┆ 26.500909     │
# │ …          ┆ …             │
# │ nokia      ┆ 93.813072     │
# │ hanskonner ┆ 49.217576     │
# │ aopen      ┆ 89.28252      │
# │ buttkicker ┆ 166.3         │
# │ topon      ┆ 48.816476     │
# └────────────┴───────────────┘
# shape: (1_000, 2)
# ┌─────────────┬───────────────┐
# │ brand       ┆ average_price │
# │ ---         ┆ ---           │
# │ str         ┆ f64           │
# ╞═════════════╪═══════════════╡
# │ magistr     ┆ 14.023143     │
# │ jett        ┆ 10.09         │
# │ deli        ┆ 34.987333     │
# │ digis       ┆ 85.89         │
# │ soundstream ┆ 110.436914    │
# │ …           ┆ …             │
# │ coolpad     ┆ 89.84         │
# │ fluke       ┆ 447.035455    │
# │ ventura     ┆ 15.24         │
# │ id-cooling  ┆ 29.731698     │
# │ verus       ┆ 6.310755      │
# └─────────────┴───────────────┘
# shape: (1_000, 2)
# ┌─────────────┬───────────────┐
# │ brand       ┆ average_price │
# │ ---         ┆ ---           │
# │ str         ┆ f64           │
# ╞═════════════╪═══════════════╡
# │ datalogic   ┆ 97.0035       │
# │ wwq         ┆ 29.86         │
# │ xtrememac   ┆ 40.63         │
# │ fiio        ┆ 216.781714    │
# │ vari        ┆ 22.7312       │
# │ …           ┆ …             │
# │ biostal     ┆ 23.374286     │
# │ iottie      ┆ 47.78         │
# │ akenori     ┆ 145.86        │
# │ oral-b      ┆ 73.061667     │
# │ funtastique ┆ 47.715161     │
# └─────────────┴───────────────┘
# shape: (1_000, 2)
# ┌───────────┬───────────────┐
# │ brand     ┆ average_price │
# │ ---       ┆ ---           │
# │ str       ┆ f64           │
# ╞═══════════╪═══════════════╡
# │ ifans     ┆ 15.38         │
# │ memumi    ┆ 16.2575       │
# │ timberk   ┆ 55.377316     │
# │ d-link    ┆ 132.570203    │
# │ wester    ┆ 125.070571    │
# │ …         ┆ …             │
# │ lacie     ┆ 196.413043    │
# │ varta     ┆ 16.93         │
# │ alas      ┆ 32.25438      │
# │ sceye     ┆ 730.96        │
# │ jisoncase ┆ 26.279412     │
# └───────────┴───────────────┘
# shape: (1_000, 2)
# ┌─────────────┬───────────────┐
# │ brand       ┆ average_price │
# │ ---         ┆ ---           │
# │ str         ┆ f64           │
# ╞═════════════╪═══════════════╡
# │ ubtech      ┆ 197.275385    │
# │ yamaha      ┆ 347.798528    │
# │ cleanfix    ┆ 262.18        │
# │ carver      ┆ 64.052407     │
# │ iiyama      ┆ 225.741214    │
# │ …           ┆ …             │
# │ ark         ┆ 53.268556     │
# │ soundstream ┆ 110.436914    │
# │ kobra       ┆ 191.510645    │
# │ bresser     ┆ 81.27         │
# │ microlife   ┆ 46.467246     │
# └─────────────┴───────────────┘
# shape: (1_000, 2)
# ┌─────────────┬───────────────┐
# │ brand       ┆ average_price │
# │ ---         ┆ ---           │
# │ str         ┆ f64           │
# ╞═════════════╪═══════════════╡
# │ sleepphones ┆ 95.481667     │
# │ hitachi     ┆ 83.166967     │
# │ supermicro  ┆ 235.075675    │
# │ edimax      ┆ 146.71        │
# │ microtek    ┆ 634.38        │
# │ …           ┆ …             │
# │ hoover      ┆ 38.24386      │
# │ andis       ┆ 196.846585    │
# │ nillkin     ┆ 20.0          │
# │ maxtor      ┆ 72.19         │
# │ fluke       ┆ 447.035455    │
# └─────────────┴───────────────┘
# shape: (1_000, 2)
# ┌────────────┬───────────────┐
# │ brand      ┆ average_price │
# │ ---        ┆ ---           │
# │ str        ┆ f64           │
# ╞════════════╪═══════════════╡
# │ powercase  ┆ 39.1775       │
# │ universal  ┆ 32.40589      │
# │ atis       ┆ 48.465        │
# │ eaton      ┆ 1060.171778   │
# │ coocazoo   ┆ 78.653263     │
# │ …          ┆ …             │
# │ wits       ┆ 16.486061     │
# │ greenworks ┆ 128.157266    │
# │ jxd        ┆ 67.878989     │
# │ makel      ┆ 13.423871     │
# │ noirot     ┆ 150.4275      │
# └────────────┴───────────────┘
# shape: (1_000, 2)
# ┌─────────┬───────────────┐
# │ brand   ┆ average_price │
# │ ---     ┆ ---           │
# │ str     ┆ f64           │
# ╞═════════╪═══════════════╡
# │ knipex  ┆ 54.24         │
# │ oukitel ┆ 182.671667    │
# │ spigen  ┆ 23.908255     │
# │ sunpro  ┆ 30.37         │
# │ capdase ┆ 70.33         │
# │ …       ┆ …             │
# │ fsp     ┆ 114.3         │
# │ alpine  ┆ 134.877021    │
# │ mirex   ┆ 11.997041     │
# │ darina  ┆ 149.243636    │
# │ hansa   ┆ 205.993095    │
# └─────────┴───────────────┘
# shape: (1_000, 2)
# ┌───────────┬───────────────┐
# │ brand     ┆ average_price │
# │ ---       ┆ ---           │
# │ str       ┆ f64           │
# ╞═══════════╪═══════════════╡
# │ asahi     ┆ 40.63         │
# │ revolter  ┆ 182.239333    │
# │ snr       ┆ 77.08         │
# │ inspector ┆ 151.395023    │
# │ anl       ┆ 12.49         │
# │ …         ┆ …             │
# │ royal     ┆ 38.89         │
# │ leeco     ┆ 107.332626    │
# │ gbc       ┆ 267.025283    │
# │ unify     ┆ 220.896429    │
# │ stlab     ┆ 47.41         │
# └───────────┴───────────────┘
# shape: (1_000, 2)
# ┌──────────┬───────────────┐
# │ brand    ┆ average_price │
# │ ---      ┆ ---           │
# │ str      ┆ f64           │
# ╞══════════╪═══════════════╡
# │ dors     ┆ 86.79         │
# │ auchan   ┆ 1019.095789   │
# │ playme   ┆ 143.105857    │
# │ solins   ┆ 14.995657     │
# │ pitatel  ┆ 46.877135     │
# │ …        ┆ …             │
# │ uninet   ┆ 11.5          │
# │ geha     ┆ 46.645        │
# │ revolter ┆ 182.239333    │
# │ hitachi  ┆ 83.166967     │
# │ leitz    ┆ 183.617143    │
# └──────────┴───────────────┘
# shape: (1_000, 2)
# ┌─────────────┬───────────────┐
# │ brand       ┆ average_price │
# │ ---         ┆ ---           │
# │ str         ┆ f64           │
# ╞═════════════╪═══════════════╡
# │ dayrex      ┆ 50.302821     │
# │ galanz      ┆ 133.16        │
# │ df          ┆ 15.636667     │
# │ hgst        ┆ 271.367143    │
# │ magnit      ┆ 46.03386      │
# │ …           ┆ …             │
# │ funtastique ┆ 47.715161     │
# │ zenet       ┆ 53.925        │
# │ relife      ┆ 12.0925       │
# │ akenori     ┆ 145.86        │
# │ tripplite   ┆ 117.812547    │
# └─────────────┴───────────────┘
# shape: (1_000, 2)
# ┌────────────┬───────────────┐
# │ brand      ┆ average_price │
# │ ---        ┆ ---           │
# │ str        ┆ f64           │
# ╞════════════╪═══════════════╡
# │ oukitel    ┆ 182.671667    │
# │ ginzzu     ┆ 60.383349     │
# │ navigator  ┆ 9.507755      │
# │ yaxun      ┆ 19.90331      │
# │ jabra      ┆ 152.599643    │
# │ …          ┆ …             │
# │ ultraflash ┆ 15.830068     │
# │ mobility   ┆ 12.911667     │
# │ intel      ┆ 212.532891    │
# │ mindeo     ┆ 52.946207     │
# │ apexto     ┆ 20.57         │
# └────────────┴───────────────┘
# shape: (1_000, 2)
# ┌───────────┬───────────────┐
# │ brand     ┆ average_price │
# │ ---       ┆ ---           │
# │ str       ┆ f64           │
# ╞═══════════╪═══════════════╡
# │ cadena    ┆ 19.610769     │
# │ alpenkok  ┆ 18.9775       │
# │ xtrememac ┆ 40.63         │
# │ gazer     ┆ 139.843684    │
# │ oppo      ┆ 168.723268    │
# │ …         ┆ …             │
# │ thomson   ┆ 21.171463     │
# │ jaguar    ┆ 153.986048    │
# │ carver    ┆ 64.052407     │
# │ dell      ┆ 463.895934    │
# │ gillette  ┆ 18.739556     │
# └───────────┴───────────────┘
# shape: (1_000, 2)
# ┌──────────┬───────────────┐
# │ brand    ┆ average_price │
# │ ---      ┆ ---           │
# │ str      ┆ f64           │
# ╞══════════╪═══════════════╡
# │ bakon    ┆ 51.75         │
# │ pro      ┆ 33.102667     │
# │ skyworth ┆ 216.727397    │
# │ eltax    ┆ 420.3         │
# │ kaisi    ┆ 260.785426    │
# │ …        ┆ …             │
# │ wester   ┆ 125.070571    │
# │ tomahawk ┆ 61.585725     │
# │ megaopt  ┆ 6.080388      │
# │ oral-b   ┆ 73.061667     │
# │ fujitsu  ┆ 242.92        │
# └──────────┴───────────────┘
# shape: (1_000, 2)
# ┌───────────┬───────────────┐
# │ brand     ┆ average_price │
# │ ---       ┆ ---           │
# │ str       ┆ f64           │
# ╞═══════════╪═══════════════╡
# │ singer    ┆ 190.546958    │
# │ baku      ┆ 13.164634     │
# │ midland   ┆ 34.52         │
# │ jxd       ┆ 67.878989     │
# │ peakmeter ┆ 31.27303      │
# │ …         ┆ …             │
# │ e-blue    ┆ 14.7525       │
# │ uragan    ┆ 11.961429     │
# │ snr       ┆ 77.08         │
# │ master    ┆ 377.22        │
# │ eltax     ┆ 420.3         │
# └───────────┴───────────────┘
# shape: (1_000, 2)
# ┌─────────────┬───────────────┐
# │ brand       ┆ average_price │
# │ ---         ┆ ---           │
# │ str         ┆ f64           │
# ╞═════════════╪═══════════════╡
# │ fastcharger ┆ 32.597692     │
# │ ballistix   ┆ 69.510321     │
# │ d-link      ┆ 132.570203    │
# │ urban       ┆ 61.895625     │
# │ jet.a       ┆ 22.480601     │
# │ …           ┆ …             │
# │ ozone       ┆ 36.752083     │
# │ helfer      ┆ 47.12         │
# │ switcheasy  ┆ 32.7          │
# │ itskins     ┆ 30.939094     │
# │ amd         ┆ 186.297986    │
# └─────────────┴───────────────┘
# shape: (1_000, 2)
# ┌───────────┬───────────────┐
# │ brand     ┆ average_price │
# │ ---       ┆ ---           │
# │ str       ┆ f64           │
# ╞═══════════╪═══════════════╡
# │ hyperx    ┆ 89.155553     │
# │ aukey     ┆ 34.697556     │
# │ cougar    ┆ 76.809967     │
# │ smarterra ┆ 27.814922     │
# │ ganzo     ┆ 46.98         │
# │ …         ┆ …             │
# │ steinel   ┆ 58.263333     │
# │ tomahawk  ┆ 61.585725     │
# │ anker     ┆ 34.03         │
# │ b.well    ┆ 36.302312     │
# │ scovo     ┆ 28.866        │
# └───────────┴───────────────┘
# shape: (1_000, 2)
# ┌──────────┬───────────────┐
# │ brand    ┆ average_price │
# │ ---      ┆ ---           │
# │ str      ┆ f64           │
# ╞══════════╪═══════════════╡
# │ outdoor  ┆ 29.37         │
# │ dell     ┆ 463.895934    │
# │ polaroid ┆ 9.14          │
# │ zetton   ┆ 18.815612     │
# │ yoobao   ┆ 29.16         │
# │ …        ┆ …             │
# │ raidmax  ┆ 71.698889     │
# │ inkax    ┆ 17.816623     │
# │ tenda    ┆ 36.429492     │
# │ wiiix    ┆ 13.0452       │
# │ jpn      ┆ 56.026531     │
# └──────────┴───────────────┘
# shape: (1_000, 2)
# ┌──────────┬───────────────┐
# │ brand    ┆ average_price │
# │ ---      ┆ ---           │
# │ str      ┆ f64           │
# ╞══════════╪═══════════════╡
# │ braun    ┆ 153.886523    │
# │ huayu    ┆ 11.59         │
# │ orico    ┆ 54.541005     │
# │ ionich   ┆ 10.392353     │
# │ vehicle  ┆ 47.46         │
# │ …        ┆ …             │
# │ max      ┆ 40.749737     │
# │ siemens  ┆ 697.25        │
# │ remax    ┆ 25.267401     │
# │ mirex    ┆ 11.997041     │
# │ borofone ┆ 16.050478     │
# └──────────┴───────────────┘
# shape: (1_000, 2)
# ┌────────────┬───────────────┐
# │ brand      ┆ average_price │
# │ ---        ┆ ---           │
# │ str        ┆ f64           │
# ╞════════════╪═══════════════╡
# │ hp         ┆ 161.0114      │
# │ tomahawk   ┆ 61.585725     │
# │ smarttools ┆ 30.95         │
# │ galaxy     ┆ 35.783228     │
# │ smtt       ┆ 10.373409     │
# │ …          ┆ …             │
# │ syma       ┆ 71.583113     │
# │ cello      ┆ 7.945455      │
# │ pilot      ┆ 22.759674     │
# │ supermicro ┆ 235.075675    │
# │ ubtech     ┆ 197.275385    │
# └────────────┴───────────────┘
# shape: (1_000, 2)
# ┌────────────┬───────────────┐
# │ brand      ┆ average_price │
# │ ---        ┆ ---           │
# │ str        ┆ f64           │
# ╞════════════╪═══════════════╡
# │ roccat     ┆ 87.666248     │
# │ greys      ┆ 64.644564     │
# │ hanskonner ┆ 49.217576     │
# │ luminarte  ┆ 92.92         │
# │ sanyo      ┆ 15.56         │
# │ …          ┆ …             │
# │ evga       ┆ 65.62         │
# │ rivacase   ┆ 40.065051     │
# │ thomas     ┆ 298.980634    │
# │ urbano     ┆ 85.65         │
# │ prestigio  ┆ 85.161182     │
# └────────────┴───────────────┘
# shape: (1_000, 2)
# ┌───────────┬───────────────┐
# │ brand     ┆ average_price │
# │ ---       ┆ ---           │
# │ str       ┆ f64           │
# ╞═══════════╪═══════════════╡
# │ bayerhoff ┆ 24.33         │
# │ bort      ┆ 100.844433    │
# │ masters   ┆ 54.915758     │
# │ iqfuture  ┆ 21.33475      │
# │ maxwell   ┆ 16.03         │
# │ …         ┆ …             │
# │ dyp       ┆ 10.779412     │
# │ belsis    ┆ 10.402        │
# │ huion     ┆ 313.300253    │
# │ keenetic  ┆ 122.175464    │
# │ zeon      ┆ 44.566667     │
# └───────────┴───────────────┘
# shape: (1_000, 2)
# ┌───────────┬───────────────┐
# │ brand     ┆ average_price │
# │ ---       ┆ ---           │
# │ str       ┆ f64           │
# ╞═══════════╪═══════════════╡
# │ canon     ┆ 150.605848    │
# │ pullman   ┆ 35.4304       │
# │ belsis    ┆ 10.402        │
# │ beko      ┆ 175.4036      │
# │ intex     ┆ 17.43         │
# │ …         ┆ …             │
# │ hoco      ┆ 25.737498     │
# │ polaroid  ┆ 9.14          │
# │ merrylock ┆ 329.648016    │
# │ makel     ┆ 13.423871     │
# │ centek    ┆ 39.369499     │
# └───────────┴───────────────┘
# shape: (1_000, 2)
# ┌─────────────┬───────────────┐
# │ brand       ┆ average_price │
# │ ---         ┆ ---           │
# │ str         ┆ f64           │
# ╞═════════════╪═══════════════╡
# │ steelseries ┆ 177.753333    │
# │ inkax       ┆ 17.816623     │
# │ beats       ┆ 186.0024      │
# │ andis       ┆ 196.846585    │
# │ alligator   ┆ 86.294615     │
# │ …           ┆ …             │
# │ b.well      ┆ 36.302312     │
# │ sunpro      ┆ 30.37         │
# │ oltramax    ┆ 11.93377      │
# │ nubia       ┆ 621.541297    │
# │ hanlong     ┆ 18.015714     │
# └─────────────┴───────────────┘
# 141 ms ± 5.55 ms per loop (mean ± std. dev. of 7 runs, 10 loops each)
